# %%
from experiments import Experiments

exp = Experiments()
exp.load('results/results_DIAG_1.csv')
exp.load('results/results_DIAG_2.csv')
ce_types = ['BS', 'KDE CE', 'KS CE', 'd EM 15b TCE', '15b TCE', '100b TCE', '15b CWCE', '100b CWCE']

# %%
exp.plot_RC_delta('densenet40_c10', ce_types=ce_types, save_file='RC_DIAG_densenet40_c10')

# %%
exp.plot_RC_delta('densenet161_imgnet', ce_types=ce_types, save_file='RC_DIAG_densenet161_imgnet')

# %%
exp.plot_RC_delta('pnasnet5_large_imgnet', ce_types=ce_types, save_file='RC_DIAG_pnasnet5_large_imgnet')

# %%
exp.plot_RC_delta('densenet40_c100', ce_types=ce_types, save_file='RC_DIAG_densenet40_c100')

# %%
exp.plot_RC_delta('resnet101_cars', ce_types=ce_types, save_file='RC_DIAG_resnet101_cars')

# %%
exp.plot_RC_delta('resnet101pre_cars', ce_types=ce_types, save_file='RC_DIAG_resnet101pre_cars')

# %%
exp.plot_RC_delta('resnet_wide32_c10', ce_types=ce_types, save_file='RC_DIAG_resnet_wide32_c10')

# %%
exp.plot_RC_delta('resnet_wide32_c100', ce_types=ce_types, save_file='RC_DIAG_resnet_wide32_c100')

# %%
exp.plot_RC_delta('resnet50_nts_birds', ce_types=ce_types, save_file='RC_DIAG_resnet50_nts_birds')

# %%
exp.plot_RC_delta('resnet110_c10', ce_types=ce_types, save_file='RC_DIAG_resnet110_c10')

# %%
exp.plot_RC_delta('resnet110_c100', ce_types=ce_types, save_file='RC_DIAG_resnet110_c100')

# %%
exp.plot_RC_delta('resnet50pre_cars', ce_types=ce_types, save_file='RC_DIAG_resnet50pre_cars')

# %%
exp.plot_RC_delta('resnet152_imgnet', ce_types=ce_types, save_file='RC_DIAG_resnet152_imgnet')

# %%
exp.plot_RC_delta('resnet152_sd_svhn', ce_types=ce_types, save_file='RC_DIAG_resnet152_sd_svhn')

# %%
exp.results_df
# Out:
#                     setting  ce_value  ce_RC_value       ce_type test_size  \
# 0        resnet50_nts_birds  0.207058     0.195713            BS      2897
# 1        resnet50_nts_birds  0.006989     0.001280        KDE CE      2897
# 2        resnet50_nts_birds  0.004846     0.000089         KS CE      2897
# 3        resnet50_nts_birds  0.206795     0.194073   Q 10 bs RBS      2897
# 4        resnet50_nts_birds  0.008459     0.000248  d EM 15b TCE      2897
# ...                     ...       ...          ...           ...       ...
# 4092753   resnet152_sd_svhn  0.000697     0.002439  d EM 15b TCE       100
# 4092754   resnet152_sd_svhn  0.001627     0.003594       15b TCE       100
# 4092755   resnet152_sd_svhn  0.001683     0.003718      100b TCE       100
# 4092756   resnet152_sd_svhn  0.002590     0.005547      15b CWCE       100
# 4092757   resnet152_sd_svhn  0.002691     0.005814     100b CWCE       100
#
#           runtime    exp_seed        exp_id RC_method
# ...
