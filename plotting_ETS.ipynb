# %%
from experiments import Experiments

exp = Experiments()
exp.load('results/results_ETS_1.csv')
exp.load('results/results_ETS_2.csv')
ce_types = ['BS', 'KDE CE', 'KS CE', 'd EM 15b TCE', '15b TCE', '100b TCE', '15b CWCE', '100b CWCE']

# %%
exp.plot_RC_delta('densenet40_c10', ce_types=ce_types, save_file='RC_ETS_densenet40_c10')

# %%
exp.plot_RC_delta('densenet161_imgnet', ce_types=ce_types, save_file='RC_ETS_densenet161_imgnet')

# %%
exp.plot_RC_delta('resnet110_SD_c100', ce_types=ce_types, save_file='RC_ETS_resnet110_SD_c100')

# %%
exp.plot_RC_delta('densenet40_c100', ce_types=ce_types, save_file='RC_ETS_densenet40_c100')

# %%
exp.plot_RC_delta('lenet5_c10', ce_types=ce_types, save_file='RC_ETS_lenet5_c10')

# %%
exp.plot_RC_delta('lenet5_c100', ce_types=ce_types, save_file='RC_ETS_lenet5_c100')

# %%
exp.plot_RC_delta('resnet_wide32_c10', ce_types=ce_types, save_file='RC_ETS_resnet_wide32_c10')

# %%
exp.plot_RC_delta('resnet_wide32_c100', ce_types=ce_types, save_file='RC_ETS_resnet_wide32_c100')

# %%
exp.plot_RC_delta('resnet50_birds', ce_types=ce_types, save_file='RC_ETS_resnet50_birds')

# %%
exp.plot_RC_delta('resnet110_c10', ce_types=ce_types, save_file='RC_ETS_resnet110_c10')

# %%
exp.plot_RC_delta('resnet110_c100', ce_types=ce_types, save_file='RC_ETS_resnet110_c100')

# %%
exp.plot_RC_delta('resnet110_SD_c10', ce_types=ce_types, save_file='RC_ETS_resnet110_SD_c10')

# %%
exp.plot_RC_delta('resnet152_imgnet', ce_types=ce_types, save_file='RC_ETS_resnet152_imgnet')

# %%
exp.plot_RC_delta('resnet152_SD_SVHN', ce_types=ce_types, save_file='RC_ETS_resnet152_SD_SVHN')

# %%
exp.results_df
# Out:
#                    setting  ce_value  ce_RC_value       ce_type test_size  \
# 0           densenet40_c10  0.127379     0.110290            BS     10000
# 1           densenet40_c10  0.008883     0.000526        KDE CE     10000
# 2           densenet40_c10  0.003018     0.000143         KS CE     10000
# 3           densenet40_c10  0.127140     0.109764   Q 10 bs RBS     10000
# 4           densenet40_c10  0.010695     0.000343  d EM 15b TCE     10000
# ...                    ...       ...          ...           ...       ...
# 4233389  resnet152_SD_SVHN  0.000000     0.000574  d EM 15b TCE       100
# 4233390  resnet152_SD_SVHN  0.007694     0.010172       15b TCE       100
# 4233391  resnet152_SD_SVHN  0.007736     0.010369      100b TCE       100
# 4233392  resnet152_SD_SVHN  0.014874     0.017224      15b CWCE       100
# 4233393  resnet152_SD_SVHN  0.015036     0.017781     100b CWCE       100
#
#           runtime    exp_seed        exp_id RC_method
# ...
